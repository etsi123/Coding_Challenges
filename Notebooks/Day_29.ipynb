# %% [markdown]
# ## You are given row x col grid representing a map where grid[i][j] = 1 represents land and grid[i][j] = 0 represents water.
#
# Grid cells are connected horizontally/vertically (not diagonally). The grid is completely surrounded by water, and there is exactly one island (i.e., one or more connected land cells).
#
# The island doesn't have "lakes", meaning the water inside isn't connected to the water around the island. One cell is a square with side length 1. The grid is rectangular, width and height don't exceed 100. Determine the perimeter of the island.

# %%
from IPython.display import Image
Image(filename = 'grid.png', width=500, height=500)

# %%
import numpy as np
def islandPerimeter(grid): 
    grid = np.array(grid) 
    dim1,dim2 = grid.shape[0],grid.shape[1]
    new_grid = np.zeros((dim1+2,dim2+2)) #pad zeros around the grid
    new_grid[1:1+dim1,1:1+dim2] = grid
    perim = 0 
    for x in range(1,1+dim1): 
        for y in range(1,1+dim2): 
            if new_grid[x,y] == 1: #if land, then we can evaluate how many open edges there are. 
                num1s = new_grid[x-1,y] + new_grid[x+1,y] + new_grid[x,y-1] + new_grid[x,y+1]
                num0s = 4-num1s #amoount of surrounding water. 
                perim = perim+num0s #add it to the perimeter
    return perim
print(islandPerimeter([[0,1,0,0],[1,1,1,0],[0,1,0,0],[1,1,0,0]]))
print(islandPerimeter([[1]]))
print(islandPerimeter([[1,0]]))
# Out:
# 16.0
# 4.0
# 4.0
